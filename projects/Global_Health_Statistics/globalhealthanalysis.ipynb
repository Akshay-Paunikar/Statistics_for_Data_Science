# %% [markdown]
# ### Global Health Statistics
#
# Global Health Statistics: Disease Prevalence, Treatments & Outcomes by Country
#
# #### About Dataset:
#
# This dataset provides comprehensive statistics on global health, focusing on various diseases, treatments, and outcomes. The data spans multiple countries and years, offering valuable insights for health research, epidemiology studies, and machine learning applications. The dataset includes information on the prevalence, incidence, and mortality rates of major diseases, as well as the effectiveness of treatments and healthcare infrastructure.
#
# #### Dataset Use Cases:
#
# This dataset can be used for:
#
#  - Healthcare Policy Analysis: Understanding which diseases are most prevalent and which countries require more investment in healthcare infrastructure.
#  - Epidemiological Studies: Studying the correlation between disease prevalence and socio-economic factors like income, education, and urbanization.
#  - Machine Learning Models: Training predictive models to forecast disease trends, mortality rates, and treatment effectiveness based on historical data.
#  - Global Health Research: Identifying regions that need targeted interventions or public health campaigns.

# %%
# import libraries for analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# read the dataset
ghs = pd.read_csv("Global Health Statistics.csv")

# %%
# check shape of dataset
ghs.shape
# Out:
# (1000000, 22)

# %%
# overview of first 5 records
ghs.head()
# Out:
#      Country  Year         Disease Name Disease Category  Prevalence Rate (%)  \
# 0      Italy  2013              Malaria      Respiratory                 0.95
# 1     France  2002                Ebola        Parasitic                12.46
# 2     Turkey  2015             COVID-19          Genetic                 0.91
# 3  Indonesia  2011  Parkinson's Disease       Autoimmune                 4.68
# 4      Italy  2013         Tuberculosis          Genetic                 0.83
#
#    Incidence Rate (%)  Mortality Rate (%) Age Group Gender  \
# 0                1.55                8.42      0-18   Male
# 1                8.63                8.75       61+   Male
# 2                2.35                6.22     36-60   Male
# 3                6.29                3.99      0-18  Other
# 4               13.59                7.01       61+   Male
#
#    Population Affected  ...  Hospital Beds per 1000  Treatment Type  \
# 0               471007  ...                    7.58      Medication
# ...

# %%
# datatypes of columns
ghs.dtypes
# Out:
# Country                                object
# Year                                    int64
# Disease Name                           object
# Disease Category                       object
# Prevalence Rate (%)                   float64
# Incidence Rate (%)                    float64
# Mortality Rate (%)                    float64
# Age Group                              object
# Gender                                 object
# Population Affected                     int64
# Healthcare Access (%)                 float64
# Doctors per 1000                      float64
# Hospital Beds per 1000                float64
# Treatment Type                         object
# Average Treatment Cost (USD)            int64
# Availability of Vaccines/Treatment     object
# Recovery Rate (%)                     float64
# DALYs                                   int64
# Improvement in 5 Years (%)            float64
# Per Capita Income (USD)                 int64
# ...

# %% [markdown]
# ##### Column Descriptions:
#
#  - <b>Country:</b> The name of the country where the health data was recorded.
#
#  - <b>Year:</b> The year in which the data was collected.
#
#  - <b>Disease Name:</b> The name of the disease or health condition tracked.
#
#  - <b>Disease Category:</b> The category of the disease (e.g., Infectious, Non-Communicable).
#
#  - <b>Prevalence Rate (%):</b> The percentage of the population affected by the disease.
#
#  - <b>Incidence Rate (%):</b> The percentage of new or newly diagnosed cases.
#
#  - <b>Mortality Rate (%):</b> The percentage of the affected population that dies from the disease.
#
#  - <b>Age Group:</b> The age range most affected by the disease.
#
#  - <b>Gender:</b> The gender(s) affected by the disease (Male, Female, Both).
#
#  - <b>Population Affected:</b> The total number of individuals affected by the disease.
#
#  - <b>Healthcare Access (%):</b> The percentage of the population with access to healthcare.
#
#  - <b>Doctors per 1000:</b> The number of doctors per 1000 people.
#
#  - <b>Hospital Beds per 1000:</b> The number of hospital beds available per 1000 people.
#
#  - <b>Treatment Type:</b> The primary treatment method for the disease (e.g., Medication, Surgery).
#
#  - <b>Average Treatment Cost (USD):</b> The average cost of treating the disease in USD.
#
#  - <b>Availability of Vaccines/Treatment:</b> Whether vaccines or treatments are available.
#
#  - <b>Recovery Rate (%):</b> The percentage of people who recover from the disease.
#
#  - <b>DALYs:</b> Disability-Adjusted Life Years, a measure of disease burden.
#
#  - <b>Improvement in 5 Years (%):</b> The improvement in disease outcomes over the last five years.
#
#  - <b>Per Capita Income (USD):</b> The average income per person in the country.
#
#  - <b>Education Index:</b> The average level of education in the country.
#
#  - <b>Urbanization Rate (%):</b> The percentage of the population living in urban areas.

# %%
# decriptive statistics
ghs.describe(include='all').T
# Out:
#                                         count unique        top    freq  \
# Country                               1000000     20     Russia   50532
# Year                                1000000.0    NaN        NaN     NaN
# Disease Name                          1000000     20   COVID-19   50404
# Disease Category                      1000000     11  Metabolic   91332
# Prevalence Rate (%)                 1000000.0    NaN        NaN     NaN
# Incidence Rate (%)                  1000000.0    NaN        NaN     NaN
# Mortality Rate (%)                  1000000.0    NaN        NaN     NaN
# Age Group                             1000000      4      19-35  251201
# Gender                                1000000      3       Male  333676
# Population Affected                 1000000.0    NaN        NaN     NaN
# Healthcare Access (%)               1000000.0    NaN        NaN     NaN
# Doctors per 1000                    1000000.0    NaN        NaN     NaN
# ...

# %%
# information about dataset
ghs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Country                             1000000 non-null  object
#  1   Year                                1000000 non-null  int64
#  2   Disease Name                        1000000 non-null  object
#  3   Disease Category                    1000000 non-null  object
#  4   Prevalence Rate (%)                 1000000 non-null  float64
#  5   Incidence Rate (%)                  1000000 non-null  float64
#  6   Mortality Rate (%)                  1000000 non-null  float64
#  7   Age Group                           1000000 non-null  object
#  8   Gender                              1000000 non-null  object
#  9   Population Affected                 1000000 non-null  int64
# ...

# %%
# check for missing values
ghs.isnull().sum()
# Out:
# Country                               0
# Year                                  0
# Disease Name                          0
# Disease Category                      0
# Prevalence Rate (%)                   0
# Incidence Rate (%)                    0
# Mortality Rate (%)                    0
# Age Group                             0
# Gender                                0
# Population Affected                   0
# Healthcare Access (%)                 0
# Doctors per 1000                      0
# Hospital Beds per 1000                0
# Treatment Type                        0
# Average Treatment Cost (USD)          0
# Availability of Vaccines/Treatment    0
# Recovery Rate (%)                     0
# DALYs                                 0
# Improvement in 5 Years (%)            0
# Per Capita Income (USD)               0
# Education Index                       0
# Urbanization Rate (%)                 0
# dtype: int64

# %%
# duplicate records
ghs.duplicated().sum()
# Out:
# 0

# %%
# let's begin our analysis by checking the number of countries in the dataset
ghs['Country'].nunique()
# Out:
# 20

# %%
# Year-range in dataset
np.sort(ghs['Year'].unique())
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023, 2024], dtype=int64)

# %%
# how many diseases are in the dataset
ghs['Disease Name'].value_counts()
# Out:
# COVID-19               50404
# Zika                   50313
# Dengue                 50289
# Cancer                 50285
# HIV/AIDS               50274
# Cholera                50249
# Asthma                 50122
# Leprosy                50064
# Diabetes               50020
# Rabies                 49975
# Hepatitis              49970
# Polio                  49956
# Malaria                49948
# Influenza              49919
# Tuberculosis           49862
# Alzheimer's Disease    49823
# Measles                49736
# Parkinson's Disease    49708
# Ebola                  49692
# Hypertension           49391
# Name: Disease Name, dtype: int64

# %%
# Disease categories in the dataset
ghs['Disease Category'].value_counts()
# Out:
# Metabolic         91332
# Parasitic         91178
# Genetic           91153
# Autoimmune        91153
# Neurological      91000
# Cardiovascular    90968
# Viral             90910
# Infectious        90764
# Respiratory       90588
# Bacterial         90509
# Chronic           90445
# Name: Disease Category, dtype: int64

# %%
# Let's visualize the categorical data
plt.figure(figsize=(15, 6))

# Disease Names & their counts

ax1 = plt.subplot2grid((1,2),(0,0))
sns.countplot(y='Disease Name', data=ghs, ax=ax1, order=ghs['Disease Name'].value_counts().index, palette='copper')
plt.title('Disease Names & their counts')
plt.xlabel('Counts')
plt.ylabel('Disease Names')

# Disease Categories & their counts

ax2 = plt.subplot2grid((1,2),(0,1))
sns.countplot(y='Disease Category', data=ghs, ax=ax2, order=ghs['Disease Category'].value_counts().index, palette='copper')
plt.title('Disease Categories & their counts')
plt.xlabel('Counts')
plt.ylabel('Disease Categories')

plt.tight_layout()
plt.show()

# %%
# Age Groups in the dataset
ghs['Age Group'].value_counts()
# Out:
# 19-35    251201
# 61+      249989
# 0-18     249605
# 36-60    249205
# Name: Age Group, dtype: int64

# %%
# Gender in the dataset
ghs['Gender'].value_counts()
# Out:
# Male      333676
# Female    333223
# Other     333101
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(15, 4))

# Gender distribution pie chart

ax1 = plt.subplot2grid((1,2),(0,0))
gender_counts = ghs['Gender'].value_counts()

plt.pie(gender_counts, labels=gender_counts.index, autopct=lambda p: f'{p:.2f}%\n({int(p * sum(gender_counts) / 100)})', 
        startangle=90, colors=sns.color_palette('crest'))

plt.title('Gender Distribution')

# Age Group distribution pie chart

ax2 = plt.subplot2grid((1,2),(0,1))
age_counts = ghs['Age Group'].value_counts()
plt.pie(age_counts, labels=age_counts.index, autopct=lambda p: f'{p:.2f}%\n({int(p * sum(age_counts) / 100)})', 
        startangle=90, colors=sns.color_palette('crest'))
plt.title('Age Group Distribution')

plt.tight_layout()
plt.show()

# %%
# Treatment Type in the dataset
ghs['Treatment Type'].value_counts()
# Out:
# Surgery        250528
# Therapy        250263
# Vaccination    249753
# Medication     249456
# Name: Treatment Type, dtype: int64

# %%
# Availability of Vaccine/Treatment
ghs['Availability of Vaccines/Treatment'].value_counts()
# Out:
# Yes    500354
# No     499646
# Name: Availability of Vaccines/Treatment, dtype: int64

# %%
plt.figure(figsize=(15, 4))

# Treatment Type distribution pie chart

ax1 = plt.subplot2grid((1,2),(0,0))
treat_type = ghs['Treatment Type'].value_counts()

plt.pie(treat_type, labels=treat_type.index, autopct=lambda p: f'{p:.2f}%\n({int(p * sum(treat_type) / 100)})', 
        startangle=90, colors=sns.color_palette('crest'))

plt.title('Treatment Type Distribution')

# Availability of Vaccine/Treatment pie chart

ax2 = plt.subplot2grid((1,2),(0,1))
av_trvacc = ghs['Availability of Vaccines/Treatment'].value_counts()
plt.pie(av_trvacc, labels=av_trvacc.index, autopct=lambda p: f'{p:.2f}%\n({int(p * sum(av_trvacc) / 100)})', 
        startangle=90, colors=sns.color_palette('crest'))
plt.title('Availability of Vaccine/Treatment Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insights:
#
#  - The dataset consists of 20 countries data with nearly equal counts for each country.
#
#  - The dataset contains data from the year 2000 till 2024 & it will be updated every year.
#
#  - The counts for Diseases as well as the category in which they fall also has nearly equal counts with no significant differences and includes diseases like: <b>'COVID-19', 'Zika', 'Dengue', 'Cancer', 'HIV/AIDS', 'Cholera', 'Asthma', 'Leprosy', 'Diabetes', 'Rabies', 'Hepatitis', 'Polio', 'Malaria', 'Influenza', 'Tuberculosis', 'Alzheimer's Disease', 'Measles', 'Parkinson's Disease', 'Ebola', 'Hypertension'</b> with categories: <b>'Metabolic', 'Parasitic', 'Genetic', 'Autoimmune', 'Neurological', 'Cardiovascular', 'Viral', 'Infectious', 'Respiratory', 'Bacterial', 'Chronic'.</b>
#
#  - The Gender distribution also has nearly equal counts with no significant differences between "Male", "Female" & "Others".
#
#  - Similarly, Age Group Distribution has nearly equal counts with no significant differences across groups 0-18, 19-35, 36-60, 61+.
#
#  - There are 4 Treatment Types: <b>'Surgery', 'Therapy', 'Vaccination', 'Medication'</b> with nearly equal counts with no significant differences.
#
#  - Similarly, Availability of Vaccine/Treatment Distribution has nearly equal counts with no significant differences across "Yes" & "No".
#
#  - Overall, dataset is well balanced considering the counts for categorical values and hence we have enough data to draw insights if we decided to do analysis based on categorical data.

# %%
# Numeric Features
# Prevalence Rate (%) distribution
plt.figure(figsize=(15, 4))
ghs['Prevalence Rate (%)'].plot(kind='kde', color='blue', linewidth=2, alpha=0.7, label='Prevalence Rate (%)', legend=True,
                                grid=True, xlim=(-1, 25), ylim=(0, 0.06))
plt.title('Prevalence Rate (%) Distribution')
plt.xlabel('Prevalence Rate (%)')
plt.ylabel('Frequency')
plt.show()

# %%
# Incidence Rate (%)
plt.figure(figsize=(15, 4))
ghs['Incidence Rate (%)'].plot(kind='kde', color='blue', linewidth=2, alpha=0.7, label='Incidence Rate (%)', legend=True,
                                grid=True, xlim=(-1, 25), ylim=(0, 0.08))
plt.title('Incidence Rate (%) Distribution')
plt.xlabel('Incidence Rate (%)')
plt.ylabel('Frequency')
plt.show()

# %%
# Mortality Rate (%)
plt.figure(figsize=(15, 4))
ghs['Mortality Rate (%)'].plot(kind='kde', color='blue', linewidth=2, alpha=0.7, label='Mortality Rate (%)', legend=True,
                                grid=True, xlim=(-1, 20), ylim=(0, 0.12))
plt.title('Mortality Rate (%) Distribution')
plt.xlabel('Mortality Rate (%)')
plt.ylabel('Frequency')
plt.show()

# %%
# Healthcare Access (%)
plt.figure(figsize=(15, 4))
ghs['Healthcare Access (%)'].plot(kind='kde', color='blue', linewidth=2, alpha=0.7, label='Healthcare Access (%)', legend=True,
                                grid=True, xlim=(40, 110), ylim=(0, 0.03))
plt.title('Healthcare Access (%) Distribution')
plt.xlabel('Healthcare Access (%)')
plt.ylabel('Frequency')
plt.show()

# %%
ghs['Population Affected'].describe()
# Out:
# count    1000000.000000
# mean      500735.427363
# std       288660.116648
# min         1000.000000
# 25%       250491.250000
# 50%       501041.000000
# 75%       750782.000000
# max      1000000.000000
# Name: Population Affected, dtype: float64

# %%
# Population Affected
plt.figure(figsize=(15, 4))
ghs['Population Affected'].plot(kind='kde', color='blue', linewidth=2, alpha=0.7, label='Population Affected', legend=True,
                                grid=True)
plt.title('Population Affected Distribution')
plt.xlabel('Population Affected')
plt.ylabel('Frequency')
plt.show()
